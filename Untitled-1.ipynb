# %%
import pandas as pd
test = pd.read_excel("COPA-MT-MK.BG.TR.MT.IS.HR.xlsx", sheet_name="test").dropna(axis=1, how="all")
dev = pd.read_excel("COPA-MT-MK.BG.TR.MT.IS.HR.xlsx", sheet_name="dev").dropna(axis=1, how="all")
train = pd.read_excel("COPA-MT-MK.BG.TR.MT.IS.HR.xlsx", sheet_name="train").dropna(axis=1, how="all")

# %%
test
# Out:
#                                                premise  \
# 0                The item was packaged in bubble wrap.
# 1                                I emptied my pockets.
# 2                          Termites invaded the house.
# 3                    The travelers reached the border.
# 4                               The office was closed.
# ..                                                 ...
# 495   The runner sensed his competitor gaining on him.
# 496             I thought carefully about the problem.
# 497  The traveler walked on the shaky suspension br...
# 498            The man anticipated the team's victory.
# 499                      The boy couldn't fall asleep.
#
#                                        answer1  \
# 0                              It was fragile.
# 1                   I retrieved a ticket stub.
# 2     The termites disappeared from the house.
# 3    The patrol agent checked their passports.
# 4                            It was a holiday.
# ...

# %%
test.head(2)
# Out:
#                                  premise                     answer1  \
# 0  The item was packaged in bubble wrap.             It was fragile.
# 2                  I emptied my pockets.  I retrieved a ticket stub.
#
#              answer2 asks-for  response  gold
# 0      It was small.    cause       NaN   1.0
# 2  I found a weapon.   effect       NaN   1.0

# %%
test.dropna(subset="asks-for").shape
# Out:
# (500, 6)
